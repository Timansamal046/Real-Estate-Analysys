# %% [markdown]
# <a href="https://colab.research.google.com/github/Timansamal046/Real-Estate-Analysys/blob/main/merge_flats_houses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('/content/flats_cleaned.csv')
houses = pd.read_csv('/content/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df.shape
# Out:
# (3961, 20)

# %%
df = df.sample(df.shape[0],ignore_index=True)
df.head()
# Out:
#                       property_name property_type                  society  \
# 0  3 BHK Flat in Sector 109 Gurgaon          flat           ats tourmaline
# 1   2 BHK Flat in Sector 91 Gurgaon          flat               tarc maceo
# 2   3 BHK Flat in Sector 77 Gurgaon          flat       emaar palm heights
# 3   3 BHK Flat in Sector 79 Gurgaon          flat       mapsko mount ville
# 4  3 BHK Flat in Sector 102 Gurgaon          flat  adani m2k oyster grande
#
#    price  price_per_sqft    area  \
# 0   2.10          8123.0  2585.0
# 1   0.89          6339.0  1404.0
# 2   2.10         10370.0  2025.0
# 3   1.20          8052.0  1490.0
# 4   1.95          7561.0  2579.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 2585(240.15 sq.m.)Built Up...        3         4
# 1  Super Built up area 1404(130.44 sq.m.)Carpet a...        2         2
# 2             Super Built up area 2025(188.13 sq.m.)        3         3
# ...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
